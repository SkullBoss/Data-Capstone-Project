# %% [markdown]
# ## Importing Libraries

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# ## Setting timeframe

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %% [markdown]
# ## Importing Data from various Bank API

# %%
# Bank Of America
BAC = data.get_data_yahoo('BAC', start , end)

# CitiGroup
C = data.get_data_yahoo('C', start ,end)

# Goldman Sachs
GS = data.get_data_yahoo('GS', start, end)

# JPMorgan Chase
JPM = data.get_data_yahoo('JPM',start, end)

# Morgan Stanley
MS = data.get_data_yahoo('MS',start, end)

# Wells Fargo
WFC = data.get_data_yahoo('WFC',start, end)

# %% [markdown]
# ## Creating Ticker Symbol

# %%
tickers = ['BAC','C','GS','JPM','MS','WFC']

# %%
bank_stocks = pd.concat([BAC, C,GS, JPM, MS, WFC], axis=1,keys= tickers)

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   35.953278  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   35.571438  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   35.617275  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %% [markdown]
# ## Max Close price  for each back's stock

# %%
#for tick in tickers:
#    print(tick, bank_stocks[tick]['Close'].max())

# %%
#alternate way
bank_stocks.xs(key='Close', axis=1, level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %% [markdown]
# ## Creating DataFrame 'returns' containing returns of each back's stock

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Returns'] = bank_stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#             BAC Returns  C Returns  GS Returns  JPM Returns  MS Returns  \
# Date
# 2006-01-03          NaN        NaN         NaN          NaN         NaN
# 2006-01-04    -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2006-01-05     0.001288   0.004961   -0.000393     0.003029    0.002742
# 2006-01-06    -0.001501   0.000000    0.014169     0.007046    0.001025
# 2006-01-09     0.000644  -0.004731    0.012030     0.016242    0.010586
#
#             WFC Returns
# Date
# 2006-01-03          NaN
# 2006-01-04    -0.011599
# 2006-01-05    -0.001110
# 2006-01-06     0.005874
# 2006-01-09    -0.000158

# %% [markdown]
# ## Creating Pair Plot using Seaborn

# %%
import seaborn as sns
sns.pairplot(returns[1:])

# %%
returns.idxmin()
# Out:
# BAC Returns   2009-01-20
# C Returns     2009-02-27
# GS Returns    2009-01-20
# JPM Returns   2009-01-20
# MS Returns    2008-10-09
# WFC Returns   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Returns   2009-04-09
# C Returns     2008-11-24
# GS Returns    2008-11-24
# JPM Returns   2009-01-21
# MS Returns    2008-10-13
# WFC Returns   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ## Riskiest stock

# %%
returns.std()
# Out:
# BAC Returns    0.036647
# C Returns      0.038672
# GS Returns     0.025390
# JPM Returns    0.027667
# MS Returns     0.037819
# WFC Returns    0.030238
# dtype: float64

# %% [markdown]
# ## Riskiest Stock in 2015

# %%
returns.ix['2015-01-01': '2015-12-31'].std()
# Out:
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# BAC Returns    0.016163
# C Returns      0.015289
# GS Returns     0.014046
# JPM Returns    0.014017
# MS Returns     0.016249
# WFC Returns    0.012591
# dtype: float64

# %% [markdown]
# ## Creating displot in seaborn for 2015 return of Morgan Stanley

# %%
sns.distplot(returns.ix['2015-01-01':'2015-12-31']['MS Returns'], color='red', bins=50)
# Out:
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Creating DistPlot using Seaborn for 2008 retyrbs of CitiGroup

# %%
sns.distplot(returns.ix['2008-01-01':'2008-12-31']['C Returns'],color='green',bins=100)
# Out:
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Import for other libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

import plotly 
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Plot Showing Close Price for entire time period

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(12,4),label=tick)
plt.legend()

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').plot(figsize=(12,4))

# %%
#plotly
bank_stocks.xs(key='Close', axis=1, level='Stock Info').iplot()
# Out:
# <div>
#
#
#             <div id="9363d59a-b193-4993-b277-3816e4fd2d56" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9363d59a-b193-4993-b277-3816e4fd2d56")) {
#                     Plotly.newPlot(
#                         '9363d59a-b193-4993-b277-3816e4fd2d56',
# ...

# %% [markdown]
# ## Plotting 30 Days average against the Close Price of Bank Of America's Stock for 2008

# %%
BAC.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.953278
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  35.571438
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  35.617275
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  35.563797
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  35.586720

# %%
plt.figure(figsize=(12,4))
BAC['Close'].ix['2008-01-01': '2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
BAC['Close'].ix['2008-01-01': '2009-01-01'].plot(label='BAC CLOSE')
plt.legend()
# Out:
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %% [markdown]
# ## Heatmap of correlation btw stock close price

# %%
sns.heatmap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(),annot=True)

# %%
close_corr = bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="eef050e6-d955-437e-a27f-4e6d90d40624" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eef050e6-d955-437e-a27f-4e6d90d40624")) {
#                     Plotly.newPlot(
#                         'eef050e6-d955-437e-a27f-4e6d90d40624',
# ...

# %%
sns.clustermap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %%
BAC[['Open', 'High', 'Low', 'Close']].ix['2015-01-01':'2016-01-01'].iplot(kind='candle')
# Out:
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# <div>
#
#
#             <div id="45b638e5-c130-40a6-9c31-fe40773553e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("45b638e5-c130-40a6-9c31-fe40773553e5")) {
#                     Plotly.newPlot(
#                         '45b638e5-c130-40a6-9c31-fe40773553e5',
# ...

# %%
MS['Close'].ix['2015-01-01':'2016-01-01'].ta_plot(study='sma',periods=[13,21,55],title='Simple Moving Averages')
# Out:
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# <div>
#
#
#             <div id="8e120a7c-2528-4829-9a84-54981fc6992b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8e120a7c-2528-4829-9a84-54981fc6992b")) {
#                     Plotly.newPlot(
#                         '8e120a7c-2528-4829-9a84-54981fc6992b',
# ...

# %%
BAC['Close'].ix['2015-01-01':'2016-01-01'].ta_plot(study='boll')
# Out:
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# <div>
#
#
#             <div id="7af459dc-5062-454c-b6a4-09b956c689f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7af459dc-5062-454c-b6a4-09b956c689f5")) {
#                     Plotly.newPlot(
#                         '7af459dc-5062-454c-b6a4-09b956c689f5',
# ...
